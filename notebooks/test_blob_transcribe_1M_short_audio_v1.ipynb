# %%
import bigframes
bigframes.options.experiments.blob = True
#bigframes.options._bigquery_options.client_endpoints_override = {"bqclient": "https://test-bigquery.sandbox.google.com", 
#                                                           "bqconnectionclient": "test-bigqueryconnection.sandbox.googleapis.com", 
#                                                           "bqstoragereadclient": "test-bigquerystorage-grpc.sandbox.googleapis.com"}
import bigframes.pandas as bpd
# Out:
# /usr/local/google/home/shuowei/src/python-bigquery-dataframes/bigframes/_config/experiment_options.py:71: ApiDeprecationWarning: BigFrames Blob is in preview now. This flag is no longer needed.
#   warnings.warn(msg, category=bfe.ApiDeprecationWarning)

# %%
df = bpd.from_glob_path("gs://shuowei_bucket/audio/*", name="audio")
# Out:
# /usr/local/google/home/shuowei/src/python-bigquery-dataframes/bigframes/core/global_session.py:103: DefaultLocationWarning: No explicit location is set, so using location US for the session.
#   _global_session = bigframes.session.connect(
# Query job 111af7c8-313c-4884-b630-632a4b1ea5fe is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-dev&j=bq:US:111af7c8-313c-4884-b630-632a4b1ea5fe&page=queryresults">Open Job</a>
# Query job 3a680a1a-208b-4c9f-8637-eb048b0a651d is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-dev&j=bq:US:3a680a1a-208b-4c9f-8637-eb048b0a651d&page=queryresults">Open Job</a>

# %%
# copy files again, now we have 1000 audio files
copies = [df] * 2 * 100
df = bpd.concat(copies, ignore_index=True)
df = df.cache()
# Out:
# Query job ce7097d7-b758-49d4-af1b-3963f44c7df3 is DONE. 354.8 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-dev&j=bq:US:ce7097d7-b758-49d4-af1b-3963f44c7df3&page=queryresults">Open Job</a>

# %%
# copy files again, now we have 1,000,000 audio files
copies = [df] * 2 * 100
df = bpd.concat(copies, ignore_index=True)
df = df.cache()
# Out:
# Query job f94ca3c8-fc8b-4102-ada0-c0db8c4716e1 is DONE. 96.0 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-dev&j=bq:US:f94ca3c8-fc8b-4102-ada0-c0db8c4716e1&page=queryresults">Open Job</a>

# %%
#bq_connection = "bigframes-dev.us.bigframes-default-connection"
df["text"] = df["audio"].blob.transcribe(df=df, audio_column="audio", model_name="gemini-2.0-flash-001", verbose=True)
# gemini-2.5-pro-preview-05-06
# Out:
# Query job 0a889fd5-0cc6-4f1d-8154-30fb00b394be is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-dev&j=bq:US:0a889fd5-0cc6-4f1d-8154-30fb00b394be&page=queryresults">Open Job</a>
# Query job 853cc347-ae70-4d1a-aa20-c5801153217f is RUNNING. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-dev&j=bq:US:853cc347-ae70-4d1a-aa20-c5801153217f&page=queryresults">Open Job</a>
# Requested cancellation for Query job 853cc347-ae70-4d1a-aa20-c5801153217f in location US...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 #bq_connection = "bigframes-dev.us.bigframes-default-connection"
# ----> 2 df["text"] = df["audio"].blob.transcribe(df=df, audio_column="audio", model_name="gemini-2.0-flash-001", verbose=True)
#       3 # gemini-2.5-pro-preview-05-06
#
# File ~/src/python-bigquery-dataframes/bigframes/core/log_adapter.py:175, in method_logger.<locals>.wrapper(*args, **kwargs)
#     172 _call_stack.append(full_method_name)
#     174 try:
# --> 175     return method(*args, **kwargs)
#     176 except (NotImplementedError, TypeError) as e:
#     177     # Log method parameters that are implemented in pandas but either missing (TypeError)
#     178     # or not fully supported (NotImplementedError) in BigFrames.
#     179     # Logging is currently supported only when we can access the bqclient through
#     180     # _block.session.bqclient.
#     181     if len(_call_stack) == 1:
#
# File ~/src/python-bigquery-dataframes/bigframes/operations/blob.py:820, in BlobAccessor.transcribe(self, df, audio_column, model_name, prompt_text, temperature, output_schema, verbose)
#     817 model = llm.GeminiTextGenerator(model_name=model_name)
#     819 # transcribe audio using ML.GENERATE_TEXT
# --> 820 results = model.predict(
#     821     X=df_prompt,
#     822     prompt=[df_prompt["prompt"], df_prompt[audio_column]],
#     823     temperature=temperature,
#     824     output_schema=output_schema,
#     825 )
#     827 content_series = cast(bpd.Series, results[transcribe_col_name])
#     829 if verbose:
#
# File ~/src/python-bigquery-dataframes/bigframes/core/log_adapter.py:175, in method_logger.<locals>.wrapper(*args, **kwargs)
#     172 _call_stack.append(full_method_name)
#     174 try:
# --> 175     return method(*args, **kwargs)
#     176 except (NotImplementedError, TypeError) as e:
#     177     # Log method parameters that are implemented in pandas but either missing (TypeError)
#     178     # or not fully supported (NotImplementedError) in BigFrames.
#     179     # Logging is currently supported only when we can access the bqclient through
#     180     # _block.session.bqclient.
#     181     if len(_call_stack) == 1:
#
# File ~/src/python-bigquery-dataframes/bigframes/ml/llm.py:738, in GeminiTextGenerator.predict(self, X, temperature, max_output_tokens, top_k, top_p, ground_with_google_search, max_retries, prompt, output_schema)
#     734     output_schema = {
#     735         k: utils.standardize_type(v) for k, v in output_schema.items()
#     736     }
#     737     options["output_schema"] = output_schema
# --> 738     return self._predict_and_retry(
#     739         core.BqmlModel.generate_table_tvf,
#     740         X,
#     741         options=options,
#     742         max_retries=max_retries,
#     743     )
#     745 return self._predict_and_retry(
#     746     core.BqmlModel.generate_text_tvf,
#     747     X,
#     748     options=options,
#     749     max_retries=max_retries,
#     750 )
#
# File ~/src/python-bigquery-dataframes/bigframes/ml/base.py:266, in RetriableRemotePredictor._predict_and_retry(self, bqml_model_predict_tvf, X, options, max_retries)
#     263     warnings.warn(msg, category=RuntimeWarning)
#     264     break
# --> 266 df = bqml_model_predict_tvf.tvf(self._bqml_model, df_fail, options)
#     268 success = df[bqml_model_predict_tvf.status_col].str.len() == 0
#     269 df_succ = df[success]
#
# File ~/src/python-bigquery-dataframes/bigframes/ml/core.py:202, in BqmlModel.generate_table(self, input_data, options)
#     197 def generate_table(
#     198     self,
#     199     input_data: bpd.DataFrame,
#     200     options: dict[str, Union[int, float, bool, Mapping]],
#     201 ) -> bpd.DataFrame:
# --> 202     return self._apply_ml_tvf(
#     203         input_data,
#     204         lambda source_sql: self._model_manipulation_sql_generator.ai_generate_table(
#     205             source_sql=source_sql,
#     206             struct_options=options,
#     207         ),
#     208     )
#
# File ~/src/python-bigquery-dataframes/bigframes/ml/core.py:88, in BqmlModel._apply_ml_tvf(self, input_data, apply_sql_tvf)
#      83 input_sql, index_col_ids, index_labels = input_data._to_sql_query(
#      84     include_index=True
#      85 )
#      87 result_sql = apply_sql_tvf(input_sql)
# ---> 88 df = self._session.read_gbq(result_sql, index_col=index_col_ids)
#      89 if df._has_index:
#      90     df.index.names = index_labels
#
# File ~/src/python-bigquery-dataframes/bigframes/core/log_adapter.py:175, in method_logger.<locals>.wrapper(*args, **kwargs)
#     172 _call_stack.append(full_method_name)
#     174 try:
# --> 175     return method(*args, **kwargs)
#     176 except (NotImplementedError, TypeError) as e:
#     177     # Log method parameters that are implemented in pandas but either missing (TypeError)
#     178     # or not fully supported (NotImplementedError) in BigFrames.
#     179     # Logging is currently supported only when we can access the bqclient through
#     180     # _block.session.bqclient.
#     181     if len(_call_stack) == 1:
#
# File ~/src/python-bigquery-dataframes/bigframes/session/__init__.py:445, in Session.read_gbq(self, query_or_table, index_col, columns, configuration, max_results, filters, use_cache, col_order, dry_run)
#     442     columns = col_order
#     444 if bf_io_bigquery.is_query(query_or_table):
# --> 445     return self._loader.read_gbq_query(  # type: ignore # for dry_run overload
#     446         query_or_table,
#     447         index_col=index_col,
#     448         columns=columns,
#     449         configuration=configuration,
#     450         max_results=max_results,
#     451         use_cache=use_cache,
#     452         filters=filters,
#     453         dry_run=dry_run,
#     454     )
#     455 else:
#     456     if configuration is not None:
#
# File ~/src/python-bigquery-dataframes/bigframes/session/loader.py:824, in GbqDataLoader.read_gbq_query(self, query, index_col, columns, configuration, max_results, use_cache, filters, dry_run, force_total_order)
#     819     return dry_runs.get_query_stats_with_inferred_dtypes(
#     820         query_job, list(columns), index_cols
#     821     )
#     823 # No cluster candidates as user query might not be clusterable (eg because of ORDER BY clause)
# --> 824 destination, query_job = self._query_to_destination(
#     825     query,
#     826     cluster_candidates=[],
#     827     configuration=configuration,
#     828 )
#     830 if self._metrics is not None:
#     831     self._metrics.count_job_stats(query_job)
#
# File ~/src/python-bigquery-dataframes/bigframes/session/loader.py:906, in GbqDataLoader._query_to_destination(self, query, cluster_candidates, configuration, do_clustering)
#     902 try:
#     903     # Write to temp table to workaround BigQuery 10 GB query results
#     904     # limit. See: internal issue 303057336.
#     905     job_config.labels["error_caught"] = "true"
# --> 906     _, query_job = self._start_query(
#     907         query,
#     908         job_config=job_config,
#     909         timeout=timeout,
#     910     )
#     911     return query_job.destination, query_job
#     912 except google.api_core.exceptions.BadRequest:
#     913     # Some SELECT statements still aren't compatible with cluster
#     914     # tables as the destination. For example, if the query has a
#     915     # top-level ORDER BY, this conflicts with our ability to cluster
#     916     # the table by the index column(s).
#
# File ~/src/python-bigquery-dataframes/bigframes/session/loader.py:937, in GbqDataLoader._start_query(self, sql, job_config, timeout)
#     932 if bigframes.options.compute.maximum_bytes_billed is not None:
#     933     # Maybe this should be pushed down into start_query_with_client
#     934     job_config.maximum_bytes_billed = (
#     935         bigframes.options.compute.maximum_bytes_billed
#     936     )
# --> 937 iterator, query_job = bf_io_bigquery.start_query_with_client(
#     938     self._bqclient,
#     939     sql,
#     940     job_config=job_config,
#     941     timeout=timeout,
#     942 )
#     943 assert query_job is not None
#     944 return iterator, query_job
#
# File ~/src/python-bigquery-dataframes/bigframes/session/_io/bigquery/__init__.py:280, in start_query_with_client(bq_client, sql, job_config, location, project, timeout, metrics, query_with_job)
#     278 opts = bigframes.options.display
#     279 if opts.progress_bar is not None and not query_job.configuration.dry_run:
# --> 280     results_iterator = formatting_helpers.wait_for_query_job(
#     281         query_job,
#     282         progress_bar=opts.progress_bar,
#     283     )
#     284 else:
#     285     results_iterator = query_job.result()
#
# File ~/src/python-bigquery-dataframes/bigframes/formatting_helpers.py:149, in wait_for_query_job(query_job, max_results, page_size, progress_bar)
#     147 loading_bar = display.HTML(get_query_job_loading_html(query_job))
#     148 display.display(loading_bar, display_id=display_id)
# --> 149 query_result = query_job.result(
#     150     max_results=max_results, page_size=page_size
#     151 )
#     152 query_job.reload()
#     153 display.update_display(
#     154     display.HTML(get_query_job_loading_html(query_job)),
#     155     display_id=display_id,
#     156 )
#
# File ~/src/python-bigquery-dataframes/venv/lib/python3.10/site-packages/google/cloud/bigquery/job/query.py:1681, in QueryJob.result(self, page_size, max_results, retry, timeout, start_index, job_retry)
#    1676     remaining_timeout = None
#    1678 if remaining_timeout is None:
#    1679     # Since is_job_done() calls jobs.getQueryResults, which is a
#    1680     # long-running API, don't delay the next request at all.
# -> 1681     while not is_job_done():
#    1682         pass
#    1683 else:
#    1684     # Use a monotonic clock since we don't actually care about
#    1685     # daylight savings or similar, just the elapsed time.
#
# File ~/src/python-bigquery-dataframes/venv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     289 target = functools.partial(func, *args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File ~/src/python-bigquery-dataframes/venv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     142 for sleep in sleep_generator:
#     143     try:
# --> 144         result = target()
#     145         if inspect.isawaitable(result):
#     146             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File ~/src/python-bigquery-dataframes/venv/lib/python3.10/site-packages/google/cloud/bigquery/job/query.py:1650, in QueryJob.result.<locals>.is_job_done()
#    1644         return True
#    1646 # Call jobs.getQueryResults with max results set to 0 just to
#    1647 # wait for the query to finish. Unlike most methods,
#    1648 # jobs.getQueryResults hangs as long as it can to ensure we
#    1649 # know when the query has finished as soon as possible.
# -> 1650 self._reload_query_results(retry=retry, **reload_query_results_kwargs)
#    1652 # Even if the query is finished now according to
#    1653 # jobs.getQueryResults, we'll want to reload the job status if
#    1654 # it's not already DONE.
#    1655 return False
#
# File ~/src/python-bigquery-dataframes/venv/lib/python3.10/site-packages/google/cloud/bigquery/job/query.py:1448, in QueryJob._reload_query_results(self, retry, timeout, page_size)
#    1445     if not isinstance(transport_timeout, (float, int)):
#    1446         transport_timeout = None
# -> 1448 self._query_results = self._client._get_query_results(
#    1449     self.job_id,
#    1450     retry,
#    1451     project=self.project,
#    1452     timeout_ms=timeout_ms,
#    1453     location=self.location,
#    1454     timeout=transport_timeout,
#    1455     page_size=page_size,
#    1456 )
#
# File ~/src/python-bigquery-dataframes/venv/lib/python3.10/site-packages/google/cloud/bigquery/client.py:2034, in Client._get_query_results(self, job_id, retry, project, timeout_ms, location, timeout, page_size)
#    2030 # This call is typically made in a polling loop that checks whether the
#    2031 # job is complete (from QueryJob.done(), called ultimately from
#    2032 # QueryJob.result()). So we don't need to poll here.
#    2033 span_attributes = {"path": path}
# -> 2034 resource = self._call_api(
#    2035     retry,
#    2036     span_name="BigQuery.getQueryResults",
#    2037     span_attributes=span_attributes,
#    2038     method="GET",
#    2039     path=path,
#    2040     query_params=extra_params,
#    2041     timeout=timeout,
#    2042 )
#    2043 return _QueryResults.from_api_repr(resource)
#
# File ~/src/python-bigquery-dataframes/venv/lib/python3.10/site-packages/google/cloud/bigquery/client.py:843, in Client._call_api(self, retry, span_name, span_attributes, job_ref, headers, **kwargs)
#     839 if span_name is not None:
#     840     with create_span(
#     841         name=span_name, attributes=span_attributes, client=self, job_ref=job_ref
#     842     ):
# --> 843         return call()
#     845 return call()
#
# File ~/src/python-bigquery-dataframes/venv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     289 target = functools.partial(func, *args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File ~/src/python-bigquery-dataframes/venv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     142 for sleep in sleep_generator:
#     143     try:
# --> 144         result = target()
#     145         if inspect.isawaitable(result):
#     146             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File ~/src/python-bigquery-dataframes/venv/lib/python3.10/site-packages/google/cloud/_http/__init__.py:482, in JSONConnection.api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object, timeout, extra_api_info)
#     479     data = json.dumps(data)
#     480     content_type = "application/json"
# --> 482 response = self._make_request(
#     483     method=method,
#     484     url=url,
#     485     data=data,
#     486     content_type=content_type,
#     487     headers=headers,
#     488     target_object=_target_object,
#     489     timeout=timeout,
#     490     extra_api_info=extra_api_info,
#     491 )
#     493 if not 200 <= response.status_code < 300:
#     494     raise exceptions.from_http_response(response)
#
# File ~/src/python-bigquery-dataframes/venv/lib/python3.10/site-packages/google/cloud/_http/__init__.py:341, in JSONConnection._make_request(self, method, url, data, content_type, headers, target_object, timeout, extra_api_info)
#     338     headers[CLIENT_INFO_HEADER] = self.user_agent
#     339 headers["User-Agent"] = self.user_agent
# --> 341 return self._do_request(
#     342     method, url, headers, data, target_object, timeout=timeout
#     343 )
#
# File ~/src/python-bigquery-dataframes/venv/lib/python3.10/site-packages/google/cloud/_http/__init__.py:379, in JSONConnection._do_request(self, method, url, headers, data, target_object, timeout)
#     345 def _do_request(
#     346     self, method, url, headers, data, target_object, timeout=_DEFAULT_TIMEOUT
#     347 ):  # pylint: disable=unused-argument
#     348     """Low-level helper:  perform the actual API request over HTTP.
#     349
#     350     Allows batch context managers to override and defer a request.
#    (...)
#     377     :returns: The HTTP response.
#     378     """
# --> 379     return self.http.request(
#     380         url=url, method=method, headers=headers, data=data, timeout=timeout
#     381     )
#
# File ~/src/python-bigquery-dataframes/venv/lib/python3.10/site-packages/google/auth/transport/requests.py:537, in AuthorizedSession.request(self, method, url, data, headers, max_allowed_time, timeout, **kwargs)
#     534 remaining_time = guard.remaining_timeout
#     536 with TimeoutGuard(remaining_time) as guard:
# --> 537     response = super(AuthorizedSession, self).request(
#     538         method,
#     539         url,
#     540         data=data,
#     541         headers=request_headers,
#     542         timeout=timeout,
#     543         **kwargs
#     544     )
#     545 remaining_time = guard.remaining_timeout
#     547 # If the response indicated that the credentials needed to be
#     548 # refreshed, then refresh the credentials and re-attempt the
#     549 # request.
#     550 # A stored token may expire between the time it is retrieved and
#     551 # the time the request is made, so we may need to try twice.
#
# File ~/src/python-bigquery-dataframes/venv/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/src/python-bigquery-dataframes/venv/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/src/python-bigquery-dataframes/venv/lib/python3.10/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/src/python-bigquery-dataframes/venv/lib/python3.10/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/src/python-bigquery-dataframes/venv/lib/python3.10/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/src/python-bigquery-dataframes/venv/lib/python3.10/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File ~/.pyenv/versions/3.10.15/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File ~/.pyenv/versions/3.10.15/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/.pyenv/versions/3.10.15/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/.pyenv/versions/3.10.15/lib/python3.10/socket.py:717, in SocketIO.readinto(self, b)
#     715 while True:
#     716     try:
# --> 717         return self._sock.recv_into(b)
#     718     except timeout:
#     719         self._timeout_occurred = True
#
# File ~/.pyenv/versions/3.10.15/lib/python3.10/ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1303     if flags != 0:
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#    1309     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.pyenv/versions/3.10.15/lib/python3.10/ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1161 try:
#    1162     if buffer is not None:
# -> 1163         return self._sslobj.read(len, buffer)
#    1164     else:
#    1165         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df
# Out:
# Query job ed3d84ac-2e1b-42ab-b867-58560e1a3167 is DONE. 8.8 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-dev&j=bq:US:ed3d84ac-2e1b-42ab-b867-58560e1a3167&page=queryresults">Open Job</a>
# Query job a65b6550-f250-4052-92e2-492ab58da692 is DONE. 8.8 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-dev&j=bq:US:a65b6550-f250-4052-92e2-492ab58da692&page=queryresults">Open Job</a>
#                                                audio  \
# 0  {'uri': 'gs://shuowei_bucket/audio/ID014clip.m...
# 1  {'uri': 'gs://shuowei_bucket/audio/HI009clip.m...
# 2  {'uri': 'gs://shuowei_bucket/audio/AK012clip.m...
# 3  {'uri': 'gs://shuowei_bucket/audio/CA138clip.m...
# 4  {'uri': 'gs://shuowei_bucket/audio/TX048clip.m...
#
#                                                 text
# 0  {'status': '', 'content': "I'll tell you somet...
# 1  {'status': '', 'content': "Uh, I hear that the...
# 2  {'status': '', 'content': "the soapstone carvi...
# 3  {'status': '', 'content': "was rather interest...
# 4  {'status': '', 'content': "Say this is entered...
#
# [5 rows x 2 columns]
