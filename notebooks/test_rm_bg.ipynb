# %%
import bigframes.pandas as bpd
from bigframes.ml import vision

# %%
df = bpd.from_glob_path("gs://garrettwu_bucket/img_rm_bg/*")
df
# Out:
# /usr/local/google/home/garrettwu/src/bigframes/bigframes/session/__init__.py:2047: UserWarning: No explicit location is set, so using location US for the session.
#   return Session(context)
# Query job 44ac5603-cd5a-480c-bb74-3a6fb50496ca is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-dev&j=bq:US:44ac5603-cd5a-480c-bb74-3a6fb50496ca&page=queryresults">Open Job</a>
# Query job e337d40b-c8ae-447e-8caf-28c4b888cdb0 is DONE. 110 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-dev&j=bq:US:e337d40b-c8ae-447e-8caf-28c4b888cdb0&page=queryresults">Open Job</a>
# Query job ad409990-3a08-478e-bcdf-0e90173f2a5e is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-dev&j=bq:US:ad409990-3a08-478e-bcdf-0e90173f2a5e&page=queryresults">Open Job</a>
# ...

# %%
df["uri"].blob.display()
# Out:
# Query job 83d19531-9e5e-42dd-834f-147e70fb3715 is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-dev&j=bq:US:83d19531-9e5e-42dd-834f-147e70fb3715&page=queryresults">Open Job</a>

# %%
df["img_foreground"] = df["uri"].blob.img_remove_background("img_rm_bg_output")
df
# Out:
# ---------------------------------------------------------------------------
# _OperationNotComplete                     Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.9/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     143 try:
# --> 144     result = target()
#     145     if inspect.isawaitable(result):
#
# File ~/.pyenv/versions/3.10.9/lib/python3.10/site-packages/google/api_core/future/polling.py:120, in PollingFuture._done_or_raise(self, retry)
#     119 if not self.done(retry=retry):
# --> 120     raise _OperationNotComplete()
#
# _OperationNotComplete:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df["img_foreground"] = df["uri"].blob.img_remove_background("img_rm_bg_output")
#       2 df
#
# ...
