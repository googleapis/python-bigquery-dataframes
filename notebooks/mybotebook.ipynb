# %%
import bigframes
import bigframes.pandas as bpd

# %%
df = bpd.DataFrame({'col_1': [True, False], 'col_2': [1,2]})

# %%
df.dtypes
# Out:
# col_1    boolean
# col_2      Int64
# dtype: object

# %%
df.astype('string').dtypes
# Out:
# col_1    string[pyarrow]
# col_2    string[pyarrow]
# dtype: object

# %%
df.astype({'col_1': 'string', 'col_2': 'Float64'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df.astype({'col_1': 'string', 'col_2': 'Float64'})
#
# File ~/src/python-bigquery-dataframes/bigframes/core/log_adapter.py:56, in method_logger.<locals>.wrapper(*args, **kwargs)
#      53 _call_stack.append(full_method_name)
#      55 try:
# ---> 56     return method(*args, **kwargs)
#      57 finally:
#      58     _call_stack.pop()
#
# File ~/src/python-bigquery-dataframes/bigframes/dataframe.py:391, in DataFrame.astype(self, dtype, errors)
#     389     block = self._block
#     390     for col, to_type in dtype.items():
# --> 391         block, _ = block.apply_unary_op(
#     392             col, ops.AsTypeOp(to_type, safe_cast), result_label=col
#     393         )
#     394     return DataFrame(block)
#     396 raise ValueError(f"Invalid type {type(dtype)} for dtype input.")
#
# ...
