# %%
import bigframes.pandas as bpd

df = bpd.from_glob_path("gs://garrettwu_bucket/wavs/*")
df
# Out:
# Query job 7a87d1bf-2f73-49f1-a277-d1114dfffab3 is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-dev&j=bq:US:7a87d1bf-2f73-49f1-a277-d1114dfffab3&page=queryresults">Open Job</a>
# Query job c0fd6991-0c81-48ee-b566-7ba60f8097f9 is DONE. 1.4 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-dev&j=bq:US:c0fd6991-0c81-48ee-b566-7ba60f8097f9&page=queryresults">Open Job</a>
# Query job cd208ca3-1f76-41cc-80da-677c04de6214 is DONE. 1.4 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-dev&j=bq:US:cd208ca3-1f76-41cc-80da-677c04de6214&page=queryresults">Open Job</a>
#                                              uri
# 0      gs://garrettwu_bucket/wavs/LJ008-0166.wav
# 1      gs://garrettwu_bucket/wavs/LJ045-0135.wav
# 2      gs://garrettwu_bucket/wavs/LJ016-0094.wav
# 3      gs://garrettwu_bucket/wavs/LJ017-0224.wav
# ...

# %%
# df = df.head(1000)
# df

# %%
df["text"] = df["uri"].blob.audio_transcribe()
# Out:
# Query job 1f5a59e5-4028-43d9-a954-cb8f203bf8e3 is DONE. 975.5 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-dev&j=bq:US:1f5a59e5-4028-43d9-a954-cb8f203bf8e3&page=queryresults">Open Job</a>

# %%
df
# Out:
# Query job a9580816-7c12-4915-9c9c-5c7dc68201e0 is RUNNING. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-dev&j=bq:US:a9580816-7c12-4915-9c9c-5c7dc68201e0&page=queryresults">Open Job</a>
# Requested cancellation for Query job a9580816-7c12-4915-9c9c-5c7dc68201e0 in location US...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df
#
# File ~/.pyenv/versions/3.10.9/lib/python3.10/site-packages/IPython/core/displayhook.py:268, in DisplayHook.__call__(self, result)
#     266 self.start_displayhook()
#     267 self.write_output_prompt()
# --> 268 format_dict, md_dict = self.compute_format_data(result)
#     269 self.update_user_ns(result)
#     270 self.fill_exec_result(result)
#
# ...

# %%
df.to_gbq("garrettwu.audio_transcribe_1k")
# Out:
# Query job 41f1f9c6-a0f4-44c0-8ead-d90bd7a8a6a6 is DONE. 43.0 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-dev&j=bq:US:41f1f9c6-a0f4-44c0-8ead-d90bd7a8a6a6&page=queryresults">Open Job</a>
# 'garrettwu.audio_transcribe_1k'
