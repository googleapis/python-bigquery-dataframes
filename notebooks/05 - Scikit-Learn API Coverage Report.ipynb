# %% [markdown]
# # BigFrames Scikit-Learn API Coverage Report
#
# This notebook estimates BigFrame's coverage of Scikit-Learn APIs by:
#
# 1. Loading a list of Scikit-Learn APIs
# 2. Checking if they are present in BigFrames
# 3. Matching them to a scrape of Kaggle's search
# 4. Searching them all on a dataset of 170k unique ipython notebooks queried from GitHub
#
# Note: Because of the way the library is set up, Scikit-Learn API usage can be inferred from import statements. This is a different method to the Pandas API coverage report, which examines key classes.
#
# TODO(bmil): add estimates based on Kaggle notebooks

# %%
sklearn_modules = [
    "sklearn",
    "sklearn.model_selection","sklearn.preprocessing","sklearn.metrics","sklearn.linear_model","sklearn.ensemble",
    "sklearn.tree","sklearn.neighbors","sklearn.svm","sklearn.naive_bayes","sklearn.pipeline","sklearn.decomposition",
    "sklearn.impute","sklearn.cluster","sklearn.feature_selection","sklearn.utils","sklearn.compose","sklearn.neural_network",
    "sklearn.datasets","sklearn.base","sklearn.manifold","sklearn.discriminant_analysis","sklearn.experimental",
    "sklearn.multiclass","sklearn.kernel_ridge","sklearn.feature_extraction","sklearn.dummy","sklearn.mixture",
    "sklearn.gaussian_process","sklearn.calibration","sklearn.multioutput","sklearn.inspection","sklearn.exceptions",
    "sklearn.cross_decomposition","sklearn.random_projection","sklearn.covariance","sklearn.semi_supervised","sklearn.isotonic",
    "sklearn.kernel_approximation"]

header = ["pattern", "api", "kind", "is_in_bigframes"]
api_patterns = []
for module in sklearn_modules:
    exec(f"import {module}")
    members = eval(f"dir({module})")
    bigframes_has_module = False
    bigframes_members = []
    try:
        bigframes_module = module.replace("sklearn", "bigframes.ml")
        exec(f"import {bigframes_module}")
        bigframes_has_module = True
        bigframes_members = eval(f"dir({bigframes_module})")
    except ImportError as e:
        pass

    api_patterns.append([
        f"from {module} import ",
        module,
        "module",
        bigframes_has_module,
    ])
    for member in members:
        # skip private functions and properties
        if member[0] == "_":
            continue
        
        api_patterns.append([
            rf"from {module} import [^\n]*\b{member}\b",
            member,
            "api",
            member in bigframes_members
        ])

import pandas as pd
pandas_df = pd.DataFrame(api_patterns, columns=header)
pandas_df
# Out:
#                                                pattern               api  \
# 0                                 from sklearn import            sklearn
# 1                   from sklearn import [^\n]*\bbase\b              base
# 2                  from sklearn import [^\n]*\bclone\b             clone
# 3         from sklearn import [^\n]*\bconfig_context\b    config_context
# 4             from sklearn import [^\n]*\bexceptions\b        exceptions
# ..                                                 ...               ...
# 815  from sklearn.kernel_approximation import [^\n]...  pairwise_kernels
# 816  from sklearn.kernel_approximation import [^\n]...   safe_sparse_dot
# 817  from sklearn.kernel_approximation import [^\n]...                sp
# 818  from sklearn.kernel_approximation import [^\n]...               svd
# 819  from sklearn.kernel_approximation import [^\n]...          warnings
#
#        kind  is_in_bigframes
# 0    module             True
# 1       api            False
# 2       api            False
# 3       api            False
# 4       api            False
# ..      ...              ...
# 815     api            False
# 816     api            False
# 817     api            False
# 818     api            False
# 819     api            False
#
# [820 rows x 4 columns]

# %% [markdown]
# This query will count the occurrence of the API patterns in a dump of 170,000 deduped IPython notebooks taken from the public GitHub dataset.

# %%
import bigframes as bf
session = bf.connect()
df = session.read_pandas(pandas_df)

# Soon, we could do all this in BigFrames...... 🤞
# TODO: see how much we can rewrite
sql = f"""
WITH
  token_patterns AS ( {df.sql} ),
  github_notebooks AS (SELECT content FROM `bigframes-dev.coverage_report.github_notebooks`),
  hit_counts AS (
    SELECT
      token_patterns.pattern,
      COUNTIF(REGEXP_CONTAINS(github_notebooks.content, token_patterns.pattern)) AS matches,
      COUNT(*) AS scanned
    FROM
      token_patterns, github_notebooks
    WHERE CONTAINS_SUBSTR(github_notebooks.content, 'from sklearn')
    GROUP BY token_patterns.pattern
    ORDER BY matches DESC
)
SELECT token_patterns.*, hit_counts.matches, hit_counts.scanned
FROM token_patterns, hit_counts
WHERE token_patterns.pattern = hit_counts.pattern
"""

df = session.read_gbq(sql)

df
# Out:
#                                              pattern api kind  \
# 0       from sklearn.naive_bayes import [^\n]*\bnp\b  np  api
# 1          from sklearn.pipeline import [^\n]*\bnp\b  np  api
# 2             from sklearn.utils import [^\n]*\bnp\b  np  api
# 3              from sklearn.base import [^\n]*\bnp\b  np  api
# 4  from sklearn.discriminant_analysis import [^\n...  np  api
# 5        from sklearn.multiclass import [^\n]*\bnp\b  np  api
# 6      from sklearn.kernel_ridge import [^\n]*\bnp\b  np  api
# 7             from sklearn.dummy import [^\n]*\bnp\b  np  api
# 8       from sklearn.calibration import [^\n]*\bnp\b  np  api
# 9       from sklearn.multioutput import [^\n]*\bnp\b  np  api
#
#    is_in_bigframes  matches  scanned
# 0            False        1    18087
# 1            False       25    18087
# 2            False        1    18087
# 3            False        2    18087
# 4            False        1    18087
# 5            False        2    18087
# 6            False        0    18087
# 7            False        0    18087
# 8            False        0    18087
# 9            False        0    18087
# ...
#
# [820 rows x 6 columns]

# %%
# TODO: rewrite everything in bigframes. Too much missing right now :(","
df = df.to_pandas()

# this imports checking method has a lot of noise from other stuff it finds in the modules.
# Lets remove rows that had <10 hits
df = df[df.matches >= 10]
df
# Out:
#                                                pattern  \
# 1            from sklearn.pipeline import [^\n]*\bnp\b
# 20   from sklearn.cross_decomposition import [^\n]*...
# 22          from sklearn.manifold import [^\n]*\bMDS\b
# 23     from sklearn.decomposition import [^\n]*\bNMF\b
# 25     from sklearn.decomposition import [^\n]*\bPCA\b
# ..                                                 ...
# 815             from sklearn.random_projection import
# 816            from sklearn.feature_extraction import
# 817           from sklearn.cross_decomposition import
# 818          from sklearn.kernel_approximation import
# 819         from sklearn.discriminant_analysis import
#
#                                api    kind  is_in_bigframes  matches  scanned
# 1                               np     api            False       25    18087
# 20                             CCA     api            False       12    18087
# 22                             MDS     api            False       82    18087
# 23                             NMF     api            False       98    18087
# 25                             PCA     api            False     1515    18087
# ..                             ...     ...              ...      ...      ...
# 815      sklearn.random_projection  module            False       34    18087
# 816     sklearn.feature_extraction  module            False      295    18087
# 817    sklearn.cross_decomposition  module            False       31    18087
# 818   sklearn.kernel_approximation  module            False       39    18087
# 819  sklearn.discriminant_analysis  module            False      260    18087
#
# [267 rows x 6 columns]

# %%
apis_df = df[df.kind == "api"].copy()
modules_df = df[df.kind == "module"].copy()

# Weighted total API coverage
covered = apis_df[apis_df["is_in_bigframes"]]["matches"].sum()
total = apis_df[apis_df["is_in_bigframes"] == False]["matches"].sum()
weighted_percentage = 100 * covered / total
print(f"Weighted by use, BigFrames ML implements {round(weighted_percentage)}% of SKLearn APIs")
# Out:
# Weighted by use, BigFrames ML implements 4% of SKLearn APIs

# %%
apis_df["pct"] = apis_df["matches"] * 100 / apis_df["scanned"]
apis_df = apis_df.sort_values("pct", ascending=False)

print("The top missing APIs, and the rate at which they appear are:")
apis_df[apis_df["is_in_bigframes"] == False].head(50)
# Out:
# The top missing APIs, and the rate at which they appear are:
#                                                pattern  \
# 539  from sklearn.model_selection import [^\n]*\btr...
# 580  from sklearn.linear_model import [^\n]*\bLogis...
# 691  from sklearn.ensemble import [^\n]*\bRandomFor...
# 524  from sklearn.metrics import [^\n]*\bconfusion_...
# 408  from sklearn.preprocessing import [^\n]*\bStan...
# 413  from sklearn.metrics import [^\n]*\baccuracy_s...
# 25     from sklearn.decomposition import [^\n]*\bPCA\b
# 27               from sklearn.svm import [^\n]*\bSVC\b
# 148    from sklearn.pipeline import [^\n]*\bPipeline\b
# 676  from sklearn.metrics import [^\n]*\bclassifica...
# 643  from sklearn.neighbors import [^\n]*\bKNeighbo...
# 687  from sklearn.tree import [^\n]*\bDecisionTreeC...
# 472  from sklearn.model_selection import [^\n]*\bcr...
# 608  from sklearn.metrics import [^\n]*\bmean_squar...
# 295  from sklearn.preprocessing import [^\n]*\bLabe...
# 294  from sklearn.model_selection import [^\n]*\bGr...
# 219  from sklearn.naive_bayes import [^\n]*\bGaussi...
# 376  from sklearn.metrics import [^\n]*\broc_auc_sc...
# 207   from sklearn.datasets import [^\n]*\bload_iris\b
# 675  from sklearn.ensemble import [^\n]*\bRandomFor...
# 166     from sklearn.metrics import [^\n]*\br2_score\b
# 213    from sklearn.metrics import [^\n]*\broc_curve\b
# 155     from sklearn.metrics import [^\n]*\bf1_score\b
# 44         from sklearn.manifold import [^\n]*\bTSNE\b
# 299  from sklearn.preprocessing import [^\n]*\bMinM...
# 185        from sklearn.svm import [^\n]*\bLinearSVC\b
# 284  from sklearn.datasets import [^\n]*\bload_digi...
# 349  from sklearn.naive_bayes import [^\n]*\bMultin...
# 373  from sklearn.pipeline import [^\n]*\bmake_pipe...
# 354  from sklearn.linear_model import [^\n]*\bSGDCl...
# 57   from sklearn.model_selection import [^\n]*\bKF...
# 587  from sklearn.preprocessing import [^\n]*\bPoly...
# 350  from sklearn.preprocessing import [^\n]*\bOneH...
# 123        from sklearn.utils import [^\n]*\bshuffle\b
# 745  from sklearn.ensemble import [^\n]*\bGradientB...
# 29           from sklearn.metrics import [^\n]*\bauc\b
# 62    from sklearn.linear_model import [^\n]*\bRidge\b
# 455  from sklearn.model_selection import [^\n]*\bSt...
# 571  from sklearn.ensemble import [^\n]*\bAdaBoostC...
# 669  from sklearn.tree import [^\n]*\bDecisionTreeR...
# 484  from sklearn.metrics import [^\n]*\bprecision_...
# 160     from sklearn.metrics import [^\n]*\blog_loss\b
# 327  from sklearn.metrics import [^\n]*\brecall_sco...
# 285  from sklearn.metrics import [^\n]*\bmake_scorer\b
# 635  from sklearn.datasets import [^\n]*\bmake_clas...
# 347  from sklearn.neural_network import [^\n]*\bMLP...
# 392  from sklearn.preprocessing import [^\n]*\bLabe...
# 267  from sklearn.feature_selection import [^\n]*\b...
# 332   from sklearn.base import [^\n]*\bBaseEstimator\b
# 58    from sklearn.linear_model import [^\n]*\bLasso\b
#
#                             api kind  is_in_bigframes  matches  scanned  \
# 539            train_test_split  api            False     3282    18087
# 580          LogisticRegression  api            False     2297    18087
# 691      RandomForestClassifier  api            False     2278    18087
# 524            confusion_matrix  api            False     1793    18087
# 408              StandardScaler  api            False     1784    18087
# 413              accuracy_score  api            False     1773    18087
# 25                          PCA  api            False     1515    18087
# 27                          SVC  api            False     1380    18087
# 148                    Pipeline  api            False     1154    18087
# 676       classification_report  api            False     1135    18087
# 643        KNeighborsClassifier  api            False     1118    18087
# 687      DecisionTreeClassifier  api            False     1043    18087
# 472             cross_val_score  api            False      994    18087
# 608          mean_squared_error  api            False      912    18087
# 295                LabelEncoder  api            False      800    18087
# 294                GridSearchCV  api            False      789    18087
# 219                  GaussianNB  api            False      756    18087
# 376               roc_auc_score  api            False      750    18087
# 207                   load_iris  api            False      686    18087
# 675       RandomForestRegressor  api            False      673    18087
# 166                    r2_score  api            False      654    18087
# 213                   roc_curve  api            False      644    18087
# 155                    f1_score  api            False      609    18087
# 44                         TSNE  api            False      599    18087
# 299                MinMaxScaler  api            False      587    18087
# 185                   LinearSVC  api            False      584    18087
# 284                 load_digits  api            False      572    18087
# 349               MultinomialNB  api            False      528    18087
# 373               make_pipeline  api            False      492    18087
# 354               SGDClassifier  api            False      483    18087
# 57                        KFold  api            False      471    18087
# 587          PolynomialFeatures  api            False      467    18087
# 350               OneHotEncoder  api            False      458    18087
# 123                     shuffle  api            False      450    18087
# 745  GradientBoostingClassifier  api            False      442    18087
# 29                          auc  api            False      425    18087
# 62                        Ridge  api            False      409    18087
# 455             StratifiedKFold  api            False      401    18087
# 571          AdaBoostClassifier  api            False      390    18087
# 669       DecisionTreeRegressor  api            False      381    18087
# 484             precision_score  api            False      367    18087
# 160                    log_loss  api            False      359    18087
# 327                recall_score  api            False      348    18087
# 285                 make_scorer  api            False      311    18087
# 635         make_classification  api            False      306    18087
# 347               MLPClassifier  api            False      304    18087
# 392              LabelBinarizer  api            False      298    18087
# 267                 SelectKBest  api            False      294    18087
# 332               BaseEstimator  api            False      293    18087
# 58                        Lasso  api            False      291    18087
#
#            pct
# 539  18.145629
# 580  12.699729
# 691  12.594681
# 524   9.913197
# 408   9.863438
# 413   9.802621
# 25    8.376182
# 27    7.629789
# 148   6.380273
# 676   6.275225
# 643   6.181235
# 687   5.766573
# 472    5.49566
# 608   5.042296
# 295   4.423066
# 294   4.362249
# 219   4.179798
# 376   4.146625
# 207   3.792779
# 675   3.720905
# 166   3.615857
# 213   3.560568
# 155   3.367059
# 44    3.311771
# 299   3.245425
# 185   3.228838
# 284   3.162492
# 349   2.919224
# 373   2.720186
# 354   2.670426
# 57     2.60408
# 587   2.581965
# 350   2.532205
# 123   2.487975
# 745   2.443744
# 29    2.349754
# 62    2.261293
# 455   2.217062
# 571   2.156245
# 669   2.106485
# 484   2.029082
# 160   1.984851
# 327   1.924034
# 285   1.719467
# 635   1.691823
# 347   1.680765
# 392   1.647592
# 267   1.625477
# 332   1.619948
# 58     1.60889
