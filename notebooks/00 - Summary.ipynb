# %% [markdown]
# # Using the dataframe API

# %% [markdown]
# ### Start a BigFrames session

# %%
import bigframes
session = bigframes.connect(bigframes.Context(project='bigframes-dev'))

# %% [markdown]
# ### Initialize a dataframe for a BigQuery table

# %%
df = session.read_gbq("bigquery-public-data.ml_datasets.penguins")

# %% [markdown]
# ## View the DataFrame

# %%
df
# Out:
#                                        species     island  culmen_length_mm
# 27   Chinstrap penguin (Pygoscelis antarctica)      Dream              50.5  \
# 44   Chinstrap penguin (Pygoscelis antarctica)      Dream              50.8
# 77         Adelie Penguin (Pygoscelis adeliae)      Dream              39.2
# 97         Adelie Penguin (Pygoscelis adeliae)      Dream              36.0
# 133          Gentoo penguin (Pygoscelis papua)     Biscoe              44.0
# 273        Adelie Penguin (Pygoscelis adeliae)     Biscoe              45.6
# 281          Gentoo penguin (Pygoscelis papua)     Biscoe              46.8
# 285          Gentoo penguin (Pygoscelis papua)     Biscoe              42.9
# 286          Gentoo penguin (Pygoscelis papua)     Biscoe              46.1
# 295        Adelie Penguin (Pygoscelis adeliae)  Torgersen              37.2
# 306        Adelie Penguin (Pygoscelis adeliae)  Torgersen              36.2
# 327        Adelie Penguin (Pygoscelis adeliae)  Torgersen              41.1
# 7    Chinstrap penguin (Pygoscelis antarctica)      Dream              50.5
# 34   Chinstrap penguin (Pygoscelis antarctica)      Dream              46.1
# 87   Chinstrap penguin (Pygoscelis antarctica)      Dream              52.2
# 218          Gentoo penguin (Pygoscelis papua)     Biscoe              45.0
# 234          Gentoo penguin (Pygoscelis papua)     Biscoe              44.9
# 280          Gentoo penguin (Pygoscelis papua)     Biscoe              47.6
# 3    Chinstrap penguin (Pygoscelis antarctica)      Dream              46.5
# 28   Chinstrap penguin (Pygoscelis antarctica)      Dream              54.2
# 52   Chinstrap penguin (Pygoscelis antarctica)      Dream              42.5
# 84         Adelie Penguin (Pygoscelis adeliae)      Dream              38.3
# 115  Chinstrap penguin (Pygoscelis antarctica)      Dream              48.5
# 173          Gentoo penguin (Pygoscelis papua)     Biscoe              45.8
# 211          Gentoo penguin (Pygoscelis papua)     Biscoe              47.4
#
#      culmen_depth_mm  flipper_length_mm  body_mass_g     sex
# 27              19.6              201.0       4050.0    MALE
# 44              19.0              210.0       4100.0    MALE
# 77              21.1              196.0       4150.0    MALE
# 97              17.9              190.0       3450.0  FEMALE
# 133             13.6              208.0       4350.0  FEMALE
# 273             20.3              191.0       4600.0    MALE
# 281             16.1              215.0       5500.0    MALE
# 285             13.1              215.0       5000.0  FEMALE
# 286             15.1              215.0       5100.0    MALE
# 295             19.4              184.0       3900.0    MALE
# 306             16.1              187.0       3550.0  FEMALE
# 327             17.6              182.0       3200.0  FEMALE
# 7               18.4              200.0       3400.0  FEMALE
# 34              18.2              178.0       3250.0  FEMALE
# 87              18.8              197.0       3450.0    MALE
# 218             15.4              220.0       5050.0    MALE
# 234             13.3              213.0       5100.0  FEMALE
# 280             14.5              215.0       5400.0    MALE
# 3               17.9              192.0       3500.0  FEMALE
# 28              20.8              201.0       4300.0    MALE
# 52              17.3              187.0       3350.0  FEMALE
# 84              19.2              189.0       3950.0    MALE
# 115             17.5              191.0       3400.0    MALE
# 173             14.6              210.0       4200.0  FEMALE
# 211             14.6              212.0       4725.0  FEMALE
# ...
#
# [344 rows x 7 columns]

# %% [markdown]
# ### View the column names in the dataframe (aka columns names in the table)

# %%
df.columns
# Out:
# Index(['species', 'island', 'culmen_length_mm', 'culmen_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %% [markdown]
# ### View the table schema

# %%
df.dtypes
# Out:
# species              string[pyarrow]
# island               string[pyarrow]
# culmen_length_mm             Float64
# culmen_depth_mm              Float64
# flipper_length_mm            Float64
# body_mass_g                  Float64
# sex                  string[pyarrow]
# dtype: object

# %% [markdown]
# ### Select a subset of columns

# %%
df = df[[
    "species",
    "island",
    "body_mass_g",
]]
df
# Out:
#                                        species     island  body_mass_g
# 27   Chinstrap penguin (Pygoscelis antarctica)      Dream       4050.0
# 44   Chinstrap penguin (Pygoscelis antarctica)      Dream       4100.0
# 77         Adelie Penguin (Pygoscelis adeliae)      Dream       4150.0
# 97         Adelie Penguin (Pygoscelis adeliae)      Dream       3450.0
# 133          Gentoo penguin (Pygoscelis papua)     Biscoe       4350.0
# 273        Adelie Penguin (Pygoscelis adeliae)     Biscoe       4600.0
# 281          Gentoo penguin (Pygoscelis papua)     Biscoe       5500.0
# 285          Gentoo penguin (Pygoscelis papua)     Biscoe       5000.0
# 286          Gentoo penguin (Pygoscelis papua)     Biscoe       5100.0
# 295        Adelie Penguin (Pygoscelis adeliae)  Torgersen       3900.0
# 306        Adelie Penguin (Pygoscelis adeliae)  Torgersen       3550.0
# 327        Adelie Penguin (Pygoscelis adeliae)  Torgersen       3200.0
# 7    Chinstrap penguin (Pygoscelis antarctica)      Dream       3400.0
# 34   Chinstrap penguin (Pygoscelis antarctica)      Dream       3250.0
# 87   Chinstrap penguin (Pygoscelis antarctica)      Dream       3450.0
# 218          Gentoo penguin (Pygoscelis papua)     Biscoe       5050.0
# 234          Gentoo penguin (Pygoscelis papua)     Biscoe       5100.0
# 280          Gentoo penguin (Pygoscelis papua)     Biscoe       5400.0
# 3    Chinstrap penguin (Pygoscelis antarctica)      Dream       3500.0
# 28   Chinstrap penguin (Pygoscelis antarctica)      Dream       4300.0
# 52   Chinstrap penguin (Pygoscelis antarctica)      Dream       3350.0
# 84         Adelie Penguin (Pygoscelis adeliae)      Dream       3950.0
# 115  Chinstrap penguin (Pygoscelis antarctica)      Dream       3400.0
# 173          Gentoo penguin (Pygoscelis papua)     Biscoe       4200.0
# 211          Gentoo penguin (Pygoscelis papua)     Biscoe       4725.0
# ...
#
# [344 rows x 3 columns]

# %% [markdown]
# ### View the first ten values of a series

# %%
df['body_mass_g'].head(10)
# Out:
# 27     4050.0
# 44     4100.0
# 77     4150.0
# 97     3450.0
# 133    4350.0
# 273    4600.0
# 281    5500.0
# 285    5000.0
# 286    5100.0
# 295    3900.0
# Name: body_mass_g, dtype: Float64

# %% [markdown]
# ### Compute the mean of a series

# %%
df['body_mass_g'].mean()
# Out:
# 4201.754385964914

# %% [markdown]
# ### Filter the dataframe

# %%
df[df['body_mass_g'] >= 4000.0]
# Out:
#                                        species  island  body_mass_g
# 27   Chinstrap penguin (Pygoscelis antarctica)   Dream       4050.0
# 44   Chinstrap penguin (Pygoscelis antarctica)   Dream       4100.0
# 77         Adelie Penguin (Pygoscelis adeliae)   Dream       4150.0
# 133          Gentoo penguin (Pygoscelis papua)  Biscoe       4350.0
# 273        Adelie Penguin (Pygoscelis adeliae)  Biscoe       4600.0
# 281          Gentoo penguin (Pygoscelis papua)  Biscoe       5500.0
# 285          Gentoo penguin (Pygoscelis papua)  Biscoe       5000.0
# 286          Gentoo penguin (Pygoscelis papua)  Biscoe       5100.0
# 218          Gentoo penguin (Pygoscelis papua)  Biscoe       5050.0
# 234          Gentoo penguin (Pygoscelis papua)  Biscoe       5100.0
# 280          Gentoo penguin (Pygoscelis papua)  Biscoe       5400.0
# 28   Chinstrap penguin (Pygoscelis antarctica)   Dream       4300.0
# 173          Gentoo penguin (Pygoscelis papua)  Biscoe       4200.0
# 211          Gentoo penguin (Pygoscelis papua)  Biscoe       4725.0
# 165          Gentoo penguin (Pygoscelis papua)  Biscoe       4375.0
# 195          Gentoo penguin (Pygoscelis papua)  Biscoe       4625.0
# 282          Gentoo penguin (Pygoscelis papua)  Biscoe       5050.0
# 215          Gentoo penguin (Pygoscelis papua)  Biscoe       4625.0
# 239          Gentoo penguin (Pygoscelis papua)  Biscoe       5000.0
# 207        Adelie Penguin (Pygoscelis adeliae)  Biscoe       4100.0
# 232        Adelie Penguin (Pygoscelis adeliae)  Biscoe       4775.0
# 241          Gentoo penguin (Pygoscelis papua)  Biscoe       5300.0
# 256          Gentoo penguin (Pygoscelis papua)  Biscoe       4925.0
# 258          Gentoo penguin (Pygoscelis papua)  Biscoe       4875.0
# 266          Gentoo penguin (Pygoscelis papua)  Biscoe       6050.0
# ...
#
# [177 rows x 3 columns]

# %% [markdown]
# # Using the Remote Functions

# %% [markdown]
# ### BigFrames gives you the ability to turn your custom scalar functions into a BigQuery remote function. It requires the GCP project to be set up appropriately and the user having sufficient privileges to use them. One can find more details on it via `help` command.

# %%
help(bigframes.remote_function)
# Out:
# Help on function remote_function in module bigframes.remote_function:
#
# remote_function(input_types: 'typing.Sequence[type]', output_type: 'type', session: 'typing.Optional[Session]' = None, bigquery_client: 'typing.Optional[bigquery.Client]' = None, dataset: 'typing.Optional[str]' = None, bigquery_connection: 'typing.Optional[str]' = None, reuse: 'bool' = True)
#     Decorator to turn a user defined function into a BigQuery remote function.
#
#     Args:
#         input_types : list(type)
#             List of input data types in the user defined function.
#         output_type : type
#             Data type of the output in the user defined function.
#         session : bigframes.Session, Optional
#             BigFrames session to use for getting default project, dataset and
#             bigquery connection.
#         bigquery_client : google.cloud.bigquery.Client, Optional
#             Client to use for BigQuery operations. If this param is not provided
#             then bigquery client from the session would be used.
#         dataset : str, Optional
#             Dataset to use to create a BigQuery function. It should be in
#             `<project_id>.<dataset_name>` or `<dataset_name>` format. If this
#             param is not provided then session dataset id would be used.
#         bigquery_connection : str, Optional
#             Name of the BigQuery connection. If it is pre created in the same
#             location as the `bigquery_client.location` then it would be used,
#             otherwise it would be created dynamically assuming the user has
#             necessary priviliges. If this param is not provided then the
#             bigquery connection from the session would be used.
#         reuse : bool, Optional
#             Reuse the remote function if already exists.
#             `True` by default, which will result in reusing an existing remote
#             function (if any) that was previously created for the same udf.
#             Setting it to false would force creating a unique remote function.
#             If the required remote function does not exist then it would be
#             created irrespective of this param.
#
#     **Prerequisites:**
#         Please make sure following is setup before using this API:
#
#         1. Have the below APIs enabled for your project:
#               a. Cloud Build API
#               b. Artifact Registry API
#               c. Cloud Functions API
#               d. BigQuery Connection API
#
#            This can be done from the cloud console (change PROJECT_ID to yours):
#               https://console.cloud.google.com/apis/enableflow?apiid=cloudbuild.googleapis.com,artifactregistry.googleapis.com,cloudfunctions.googleapis.com,bigqueryconnection.googleapis.com&project=PROJECT_ID
#            Or from the gcloud CLI:
#               $ gcloud services enable cloudbuild.googleapis.com artifactregistry.googleapis.com cloudfunctions.googleapis.com bigqueryconnection.googleapis.com
#
#         2. Have following IAM roles enabled for you:
#               a. BigQuery Job User (roles/bigquery.jobUser)
#               b. BigQuery Connection User (roles/bigquery.connectionUser)
#               c. Cloud Functions Developer (roles/cloudfunctions.developer)
#
#         3. Either the user has setIamPolicy privilege on the project, or a BigQuery connection is pre-created with necessary IAM role set:
#               a. To create a connection, follow https://cloud.google.com/bigquery/docs/reference/standard-sql/remote-functions#create_a_connection
#               b. To set up IAM, follow https://cloud.google.com/bigquery/docs/reference/standard-sql/remote-functions#grant_permission_on_function
#            Alternatively, the IAM could also be setup via the gcloud CLI:
#               $ gcloud projects add-iam-policy-binding PROJECT_ID --member="serviceAccount:CONNECTION_SERVICE_ACCOUNT_ID" --role="roles/run.invoker"

# %% [markdown]
# ### Define a custom function, and specify the intent to turn it into a remote function. It requires a BigQuery connection. If the connection is not already created, BigFrames will attempt to create one assuming the necessary APIs and IAM permissions are setup in the project.

# %%
@session.remote_function([float], str, bigquery_connection='bigframes-rf-conn')
def get_bucket(num):
    if not num: return "NA"
    boundary = 4000
    return "at_or_above_4000" if num >= boundary else "below_4000"
# Out:
# [INFO][2023-05-22 09:34:30,928][bigframes.remote_function] Existing cloud functions
# NAME                                                 STATE    TRIGGER       REGION       ENVIRONMENT
# bigframes-01419d4cb41f1fdd1412f928fe2dc9a6           ACTIVE   HTTP Trigger  us-central1  2nd gen
# bigframes-03520f5affb33f215ddeb2e655cf64bf-c8psy512  ACTIVE   HTTP Trigger  us-central1  2nd gen
# bigframes-05e9ae2b1262e8c49b1ed1f54c77cb17           ACTIVE   HTTP Trigger  us-central1  2nd gen
# bigframes-065885eacaa24a6446fef6e2369697cd           ACTIVE   HTTP Trigger  us-central1  2nd gen
# bigframes-08be0bda1fb6d0c220a0bb81e4838eba           UNKNOWN  HTTP Trigger  us-central1  2nd gen
# bigframes-09841edf0f7beafb531bc507541d6c5a           ACTIVE   HTTP Trigger  us-central1  2nd gen
# bigframes-0b522e7221ebb826b2bfebbb3d5587ca           ACTIVE   HTTP Trigger  us-central1  2nd gen
# bigframes-0ebf54645abef743485844a5e84a118b           ACTIVE   HTTP Trigger  us-central1  2nd gen
# bigframes-1517f3edbba21fce76152d93000989d9           ACTIVE   HTTP Trigger  us-central1  2nd gen
# bigframes-1629854f0f8f5b2cb78cadeaae6b4306           ACTIVE   HTTP Trigger  us-central1  2nd gen
# bigframes-17648affe250b42b7a4adf0aac641583           ACTIVE   HTTP Trigger  us-central1  2nd gen
# bigframes-1b3d4af360f525fad83c35c11aa7528f-0tded9o4  ACTIVE   HTTP Trigger  us-central1  2nd gen
# bigframes-1b3d4af360f525fad83c35c11aa7528f-1hm7xl02  ACTIVE   HTTP Trigger  us-central1  2nd gen
# bigframes-1b3d4af360f525fad83c35c11aa7528f-2n6cwoeb  ACTIVE   HTTP Trigger  us-central1  2nd gen
# bigframes-1b3d4af360f525fad83c35c11aa7528f-3gygqddq  ACTIVE   HTTP Trigger  us-central1  2nd gen
# bigframes-1b3d4af360f525fad83c35c11aa7528f-4yijg3il  ACTIVE   HTTP Trigger  us-central1  2nd gen
# bigframes-1b3d4af360f525fad83c35c11aa7528f-54o9il4u  ACTIVE   HTTP Trigger  us-central1  2nd gen
# bigframes-1b3d4af360f525fad83c35c11aa7528f-5zp2gnv4  ACTIVE   HTTP Trigger  us-central1  2nd gen
# bigframes-1b3d4af360f525fad83c35c11aa7528f-695u45n1  ACTIVE   HTTP Trigger  us-central1  2nd gen
# bigframes-1b3d4af360f525fad83c35c11aa7528f-6qc7qtuh  ACTIVE   HTTP Trigger  us-central1  2nd gen
# bigframes-1b3d4af360f525fad83c35c11aa7528f-6ytzvu12  ACTIVE   HTTP Trigger  us-central1  2nd gen
# bigframes-1b3d4af360f525fad83c35c11aa7528f-72env49p  ACTIVE   HTTP Trigger  us-central1  2nd gen
# bigframes-1b3d4af360f525fad83c35c11aa7528f-7f5nwi7r  ACTIVE   HTTP Trigger  us-central1  2nd gen
# bigframes-1b3d4af360f525fad83c35c11aa7528f
UNKNOWN    HTTP Trigger  us-central1  2nd gen
# bigframes-f851cf9ae60b76c883797f0b7cb850e3-3zva7nct  ACTIVE     HTTP Trigger  us-central1  2nd gen
# bigframes-f851cf9ae60b76c883797f0b7cb850e3-97e6uwc7  ACTIVE     HTTP Trigger  us-central1  2nd gen
# bigframes-f851cf9ae60b76c883797f0b7cb850e3-f9pi2k45  ACTIVE     HTTP Trigger  us-central1  2nd gen
# bigframes-f851cf9ae60b76c883797f0b7cb850e3-gx4dvzjg  UNKNOWN    HTTP Trigger  us-central1  2nd gen
# bigframes-f851cf9ae60b76c883797f0b7cb850e3-kgwz7x3x  UNKNOWN    HTTP Trigger  us-central1  2nd gen
# bigframes-f851cf9ae60b76c883797f0b7cb850e3-kls8wzio  UNKNOWN    HTTP Trigger  us-central1  2nd gen
# bigframes-f851cf9ae60b76c883797f0b7cb850e3-kqy6p42z  UNKNOWN    HTTP Trigger  us-central1  2nd gen
# bigframes-f851cf9ae60b76c883797f0b7cb850e3-lqvxg1a3  ACTIVE     HTTP Trigger  us-central1  2nd gen
# bigframes-f851cf9ae60b76c883797f0b7cb850e3-n9ang23j  ACTIVE     HTTP Trigger  us-central1  2nd gen
# bigframes-f851cf9ae60b76c883797f0b7cb850e3-pfjvrl3e  UNKNOWN    HTTP Trigger  us-central1  2nd gen
# bigframes-f851cf9ae60b76c883797f0b7cb850e3-typbwal5  ACTIVE     HTTP Trigger  us-central1  2nd gen
# bigframes-f851cf9ae60b76c883797f0b7cb850e3-ysfuwqa7  ACTIVE     HTTP Trigger  us-central1  2nd gen
# bigframes-f851cf9ae60b76c883797f0b7cb850e3-z9phv1fd  ACTIVE     HTTP Trigger  us-central1  2nd gen
# bigframes-fab15c4849123a0a6ff3f8d46a72486f           UNKNOWN    HTTP Trigger  us-central1  2nd gen
# bigframes-fcad66fc05b426c56472b2578ad6ad99           ACTIVE     HTTP Trigger  us-central1  2nd gen
# bigframes-fdfc1be7af325c3e0f711a0af9b65ee5           ACTIVE     HTTP Trigger  us-central1  2nd gen
# bigframes-fee0053680175f1a29acb3ab51db6d69-14rbei4l  ACTIVE     HTTP Trigger  us-central1  2nd gen
# bigframes-fee0053680175f1a29acb3ab51db6d69-1ny93nvx  UNKNOWN    HTTP Trigger  us-central1  2nd gen
# bigframes-fee0053680175f1a29acb3ab51db6d69-2haafdwp  ACTIVE     HTTP Trigger  us-central1  2nd gen
# bigframes-fee0053680175f1a29acb3ab51db6d69-3q3lxql2  ACTIVE     HTTP Trigger  us-central1  2nd gen
# bigframes-fee0053680175f1a29acb3ab51db6d69-4crpcjhj  UNKNOWN    HTTP Trigger  us-central1  2nd gen
# bigframes-fee0053680175f1a29acb3ab51db6d69-748d7whx  ACTIVE     HTTP Trigger  us-central1  2nd gen
# bigframes-fee0053680175f1a29acb3ab51db6d69-f21bb20f  UNKNOWN    HTTP Trigger  us-central1  2nd gen
# bigframes-fee0053680175f1a29acb3ab51db6d69-fm9ppg23  ACTIVE     HTTP Trigger  us-central1  2nd gen
# bigframes-fee0053680175f1a29acb3ab51db6d69-kqxu5y2b  UNKNOWN    HTTP Trigger  us-central1  2nd gen
# bigframes-fee0053680175f1a29acb3ab51db6d69-kr38gv9e  UNKNOWN    HTTP Trigger  us-central1  2nd gen
# bigframes-fee0053680175f1a29acb3ab51db6d69-nl98q0vz  UNKNOWN    HTTP Trigger  us-central1  2nd gen
# bigframes-fee0053680175f1a29acb3ab51db6d69-pyuiapfc  UNKNOWN    HTTP Trigger  us-central1  2nd gen
# bigframes-fee0053680175f1a29acb3ab51db6d69-tpgrtj7h  ACTIVE     HTTP Trigger  us-central1  2nd gen
# bigframes-fee0053680175f1a29acb3ab51db6d69-tvj5vf07  ACTIVE     HTTP Trigger  us-central1  2nd gen
# bigframes-fee0053680175f1a29acb3ab51db6d69-vp4tqyj6  ACTIVE     HTTP Trigger  us-central1  2nd gen
# bigframes-ff0d2fb6b14d2150fa8ed9207dc7946b           ACTIVE     HTTP Trigger  us-central1  2nd gen
# [INFO][2023-05-22 09:35:53,263][bigframes.remote_function] Successfully created cloud function bigframes-1f5a6c9751d09766f0c886aaa1ef0f8b with uri (https://bigframes-1f5a6c9751d09766f0c886aaa1ef0f8b-7krlje3eoq-uc.a.run.app)
# [INFO][2023-05-22 09:35:54,835][bigframes.remote_function] Connector bigframes-rf-conn already exists
# [INFO][2023-05-22 09:35:54,837][bigframes.remote_function] Creating BQ remote function:
#     CREATE OR REPLACE FUNCTION `bigframes-dev.bigframes_temp_us`.bigframes_1f5a6c9751d09766f0c886aaa1ef0f8b(num FLOAT64)
#     RETURNS STRING
#     REMOTE WITH CONNECTION `bigframes-dev.us.bigframes-rf-conn`
#     OPTIONS (
#       endpoint = "https://bigframes-1f5a6c9751d09766f0c886aaa1ef0f8b-7krlje3eoq-uc.a.run.app"
#     )
# [INFO][2023-05-22 09:35:55,737][bigframes.remote_function] Created remote function bigframes-dev.bigframes_temp_us.bigframes_1f5a6c9751d09766f0c886aaa1ef0f8b

# %% [markdown]
# ### Run the custom function on the BigFrames dataframe

# %%
df = df.assign(body_mass_bucket=df['body_mass_g'].apply(get_bucket))
df[['body_mass_g', 'body_mass_bucket']].head(10)
# Out:
#      body_mass_g  body_mass_bucket
# 27        4050.0  at_or_above_4000
# 44        4100.0  at_or_above_4000
# 77        4150.0  at_or_above_4000
# 97        3450.0        below_4000
# 133       4350.0  at_or_above_4000
# 273       4600.0  at_or_above_4000
# 281       5500.0  at_or_above_4000
# 285       5000.0  at_or_above_4000
# 286       5100.0  at_or_above_4000
# 295       3900.0        below_4000
#
# [10 rows x 2 columns]

# %% [markdown]
# # Using the ML API

# %% [markdown]
# ### Start a session and initialize a dataframe for a BigQuery table

# %%
df = session.read_gbq("bigquery-public-data.ml_datasets.penguins")
df
# Out:
#                                        species     island  culmen_length_mm
# 37   Chinstrap penguin (Pygoscelis antarctica)      Dream              51.7  \
# 60   Chinstrap penguin (Pygoscelis antarctica)      Dream              46.7
# 193        Adelie Penguin (Pygoscelis adeliae)     Biscoe              35.5
# 229        Adelie Penguin (Pygoscelis adeliae)     Biscoe              36.5
# 46         Adelie Penguin (Pygoscelis adeliae)      Dream              37.5
# 57   Chinstrap penguin (Pygoscelis antarctica)      Dream              49.2
# 154        Adelie Penguin (Pygoscelis adeliae)     Biscoe              37.9
# 161          Gentoo penguin (Pygoscelis papua)     Biscoe              49.3
# 185          Gentoo penguin (Pygoscelis papua)     Biscoe              51.3
# 209        Adelie Penguin (Pygoscelis adeliae)     Biscoe              42.7
# 214          Gentoo penguin (Pygoscelis papua)     Biscoe              44.9
# 224          Gentoo penguin (Pygoscelis papua)     Biscoe              49.1
# 228        Adelie Penguin (Pygoscelis adeliae)     Biscoe              38.1
# 260          Gentoo penguin (Pygoscelis papua)     Biscoe              50.4
# 275        Adelie Penguin (Pygoscelis adeliae)     Biscoe              38.6
# 339        Adelie Penguin (Pygoscelis adeliae)  Torgersen              38.8
# 56   Chinstrap penguin (Pygoscelis antarctica)      Dream              43.2
# 71         Adelie Penguin (Pygoscelis adeliae)      Dream              32.1
# 90   Chinstrap penguin (Pygoscelis antarctica)      Dream              52.0
# 124          Gentoo penguin (Pygoscelis papua)     Biscoe              <NA>
# 168          Gentoo penguin (Pygoscelis papua)     Biscoe              49.6
# 196          Gentoo penguin (Pygoscelis papua)     Biscoe              45.4
# 200          Gentoo penguin (Pygoscelis papua)     Biscoe              53.4
# 216          Gentoo penguin (Pygoscelis papua)     Biscoe              48.4
# 272        Adelie Penguin (Pygoscelis adeliae)     Biscoe              41.4
#
#      culmen_depth_mm  flipper_length_mm  body_mass_g     sex
# 37              20.3              194.0       3775.0    MALE
# 60              17.9              195.0       3300.0  FEMALE
# 193             16.2              195.0       3350.0  FEMALE
# 229             16.6              181.0       2850.0  FEMALE
# 46              18.9              179.0       2975.0    <NA>
# 57              18.2              195.0       4400.0    MALE
# 154             18.6              193.0       2925.0  FEMALE
# 161             15.7              217.0       5850.0    MALE
# 185             14.2              218.0       5300.0    MALE
# 209             18.3              196.0       4075.0    MALE
# 214             13.8              212.0       4750.0  FEMALE
# 224             15.0              228.0       5500.0    MALE
# 228             17.0              181.0       3175.0  FEMALE
# 260             15.7              222.0       5750.0    MALE
# 275             17.2              199.0       3750.0  FEMALE
# 339             17.6              191.0       3275.0  FEMALE
# 56              16.6              187.0       2900.0  FEMALE
# 71              15.5              188.0       3050.0  FEMALE
# 90              19.0              197.0       4150.0    MALE
# 124             <NA>               <NA>         <NA>    <NA>
# 168             16.0              225.0       5700.0    MALE
# 196             14.6              211.0       4800.0  FEMALE
# 200             15.8              219.0       5500.0    MALE
# 216             16.3              220.0       5400.0    MALE
# 272             18.6              191.0       3700.0    MALE
# ...
#
# [344 rows x 7 columns]

# %% [markdown]
# ### Clean and prepare the data

# %%
# filter down to the data we want to analyze
adelie_data = df[df.species == "Adelie Penguin (Pygoscelis adeliae)"]

# drop the columns we don't care about
adelie_data = adelie_data.drop(columns=["species"])

# drop rows with nulls to get our training data
training_data = adelie_data.dropna()

# take a peek at the training data
training_data
# Out:
#         island  culmen_length_mm  culmen_depth_mm  flipper_length_mm
# 193     Biscoe              35.5             16.2              195.0  \
# 229     Biscoe              36.5             16.6              181.0
# 154     Biscoe              37.9             18.6              193.0
# 209     Biscoe              42.7             18.3              196.0
# 228     Biscoe              38.1             17.0              181.0
# 275     Biscoe              38.6             17.2              199.0
# 339  Torgersen              38.8             17.6              191.0
# 71       Dream              32.1             15.5              188.0
# 272     Biscoe              41.4             18.6              191.0
# 54       Dream              40.6             17.2              187.0
# 207     Biscoe              41.1             19.1              188.0
# 232     Biscoe              43.2             19.0              197.0
# 77       Dream              39.2             21.1              196.0
# 97       Dream              36.0             17.9              190.0
# 273     Biscoe              45.6             20.3              191.0
# 295  Torgersen              37.2             19.4              184.0
# 306  Torgersen              36.2             16.1              187.0
# 327  Torgersen              41.1             17.6              182.0
# 9        Dream              40.2             20.1              200.0
# 19       Dream              37.8             18.1              193.0
# 172     Biscoe              37.6             19.1              194.0
# 318  Torgersen              39.6             17.2              196.0
# 329  Torgersen              33.5             19.0              190.0
# 206     Biscoe              40.5             18.9              180.0
# 65       Dream              40.8             18.4              195.0
#
#      body_mass_g     sex
# 193       3350.0  FEMALE
# 229       2850.0  FEMALE
# 154       2925.0  FEMALE
# 209       4075.0    MALE
# 228       3175.0  FEMALE
# 275       3750.0  FEMALE
# 339       3275.0  FEMALE
# 71        3050.0  FEMALE
# 272       3700.0    MALE
# 54        3475.0    MALE
# 207       4100.0    MALE
# 232       4775.0    MALE
# 77        4150.0    MALE
# 97        3450.0  FEMALE
# 273       4600.0    MALE
# 295       3900.0    MALE
# 306       3550.0  FEMALE
# 327       3200.0  FEMALE
# 9         3975.0    MALE
# 19        3750.0    MALE
# 172       3750.0    MALE
# 318       3550.0  FEMALE
# 329       3600.0  FEMALE
# 206       3950.0    MALE
# 65        3900.0    MALE
# ...
#
# [146 rows x 6 columns]

# %%
# pick feature columns and label column
feature_columns = training_data[['island', 'culmen_length_mm', 'culmen_depth_mm', 'flipper_length_mm', 'sex']]
label_columns = training_data[['body_mass_g']]

# also get the rows that we want to make predictions for (i.e. where the feature column is null)
missing_body_mass = adelie_data[adelie_data.body_mass_g.isnull()]

# %% [markdown]
# ### Train and evaluate a linear regression model using the ML API

# %%
from bigframes.ml.linear_model import LinearRegression

# as in scikit-learn, a newly created model is just a bundle of parameters
# default parameters are fine here
model = LinearRegression()

# this will train a temporary model in BigQuery Machine Learning
model.fit(feature_columns, label_columns)

# check how the model performed, using the automatic test/training data split chosen by BQML
model.score()
# Out:
#    mean_absolute_error  mean_squared_error  mean_squared_log_error
# 0           223.878763        78553.601634                0.005614  \
#
#    median_absolute_error  r2_score  explained_variance
# 0             181.330911  0.623951            0.623951
#
# [1 rows x 6 columns]

# %% [markdown]
# ### Make predictions using the model

# %%
# TODO(shobs): Following expression is failing with the error:
#   ValueError: Column `index_5` of `index_cols` not found in this table.
# originating from Session.read_gbq().
# Disable for now, Enable back once fixed.
#model.predict(missing_body_mass)

# %% [markdown]
# ### Save the trained model to BigQuery, so we can load it later

# %%
model.to_gbq("bqml_tutorial.penguins_model", replace=True)
# Out:
# LinearRegression()
